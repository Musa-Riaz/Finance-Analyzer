# %% [markdown]
# # Run Categorization

# %%
import sys
sys.path.append("../src")

# %%
from finance_analyzer.ml import cluster_transactions

df_categorized = cluster_transactions(df_all, n_clusters=6)

# See what categories got assigned
df_categorized[["timestamp", "description", "amount", "category"]].head(20)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from finance_analyzer.ml import cluster_transactions
#       3 df_categorized = cluster_transactions(df_all, n_clusters=6)
#       5 # See what categories got assigned
#
# ImportError: cannot import name 'cluster_transactions' from 'finance_analyzer.ml' (C:\Users\Home PC\OneDrive\Desktop\finance-analyzer\notebooks\../src\finance_analyzer\ml.py)
